# %%
#Titanic Dataset
#Understanding DataSet
'''Sibsp: no of sibling/spouses aboard the ship
Parch: no of Parent/children aboard the ship
Embarked:From where thier journey started 
    s:southampton
    q:quiton
    c:canton city'''
#1.Collecting Data and Importing Libraries
#2.Analysing data and exploring data #whether passenger who pay are rescue first
#3.Data Wrangling or cleaning
#4.Train$Test
#5.Accuracy check
# Out:
# 'Sibsp: no of sibling/spouses aboard the ship\nParch: no of Parent/children aboard the ship\nEmbarked:From where thier journey started \n    s:southampton\n    q:quiton\n    c:canton city'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pyplot
# %matplotlib inline
import math

Titanic_Dataset=pd.read_csv('C:/Users/Lenovo/Desktop/ML course/titanic.csv')

# %%
Titanic_Dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#looking at the numper of passengers in the dataset
np.shape(Titanic_Dataset)
# Out:
# (891, 12)

# %% [markdown]
# Analyzing Data

# %%
#Analyzing Number of people Survived countplot gives nmber of categorical data 
sns.countplot(x='Survived',data=Titanic_Dataset)

# %%
#All the Passenger who survived how many were male and how many were female
sns.countplot(x='Survived',hue='Sex',data=Titanic_Dataset)

# %%
#which class psngr are survived more
sns.countplot(x='Survived',hue='Pclass',data=Titanic_Dataset)

# %%
#which age people were travelling in the ship
Titanic_Dataset['Age'].plot.hist()
#this shows that more young and middle age pssngers are more

# %%
#analyzing other columns too
Titanic_Dataset['Fare'].plot.hist(figsize=(10,5))

# %%
sns.countplot(x='SibSp',data=Titanic_Dataset)
#Here we can see maximum value is 0 neither the child or sibling aboard the titanic

# %%
sns.countplot(x='Parch',data=Titanic_Dataset)
#this shows the same

# %% [markdown]
# Data Wrangling

# %%
Titanic_Dataset.isnull()
#False where the value is not null
#True if the value is null
#Overhere the cabin column has null values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
Titanic_Dataset.isnull().sum()
#here we can see there are 177 null values in age and 687 null values in cabin and embarked as 2
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(Titanic_Dataset.isnull(),yticklabels=False)
#0-False 1-True as  null
#thus cabin has light color,color-encoded matrix

# %%
#removing the missing value
#analyzing if we can drop the column
Titanic_Dataset.head()
#since survived can be my output column on which i will perform my logistic regreesion
#x input features can be Pclass or Age or Sex so we can drop column Cabin
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Titanic_Dataset.drop('Cabin',axis=1,inplace=True)

# %%
Titanic_Dataset.head()
#no cabin column
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
Titanic_Dataset.dropna(inplace=True)

# %%
sns.heatmap(Titanic_Dataset.isnull(),yticklabels=False)
#entirely same clr no null values

# %%
Titanic_Dataset.isnull().sum()
#yes the data is cleaned
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
Titanic_Dataset.head()
#now since we have here lot of string value to implement logistic regreesion we need to convert string to categorical values
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
pd.get_dummies(Titanic_Dataset['Sex'])
#here you can see female 1 means present 0 not 
#but we dont require both column we can take only male column and 
#if male = 1 male is presnet else it is female
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# 6         0     1
# 7         0     1
# 8         1     0
# 9         1     0
# 10        1     0
# 11        1     0
# 12        0     1
# 13        0     1
# 14        1     0
# 15        1     0
# 16        0     1
# 18        1     0
# 20        0     1
# 21        0     1
# 22        1     0
# 23        0     1
# 24        1     0
# 25        1     0
# 27        0     1
# 30        0     1
# 33        0     1
# 34        0     1
# 35        0     1
# 37        0     1
# 38        1     0
# ..      ...   ...
# 856       1     0
# 857       0     1
# 858       1     0
# 860       0     1
# 861       0     1
# 862       1     0
# 864       0     1
# 865       1     0
# 866       1     0
# 867       0     1
# 869       0     1
# 870       0     1
# 871       1     0
# 872       0     1
# 873       0     1
# 874       1     0
# 875       1     0
# 876       0     1
# ...

# %%
sex=pd.get_dummies(Titanic_Dataset['Sex'],drop_first=True)
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embarked=pd.get_dummies(Titanic_Dataset['Embarked'])

# %%
embarked.head()
#here also first column is not important because pssnger is travelling in the Q or S or if both are 0 in C
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
embarked=pd.get_dummies(Titanic_Dataset['Embarked'],drop_first=True)
embarked.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
pcl=pd.get_dummies(Titanic_Dataset['Pclass'],drop_first=True)
pcl.head()
#if both 0 then 1 class
# Out:
#    2  3
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  0
# 4  0  1

# %%
data=pd.concat([Titanic_Dataset,sex,embarked,pcl],axis=1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  male  Q  S  2  3
# 0      0         A/5 21171   7.2500        S     1  0  1  0  1
# 1      0          PC 17599  71.2833        C     0  0  0  0  0
# 2      0  STON/O2. 3101282   7.9250        S     0  0  1  0  1
# ...

# %%
#now dropping irrelevent columns now
data.drop(['PassengerId','Pclass','Name','Sex','Ticket','Embarked'],axis=1,inplace=True)
data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500     1  0  1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0  0  0
# 2         1  26.0      0      0   7.9250     0  0  1  0  1
# 3         1  35.0      1      0  53.1000     0  0  1  0  0
# 4         0  35.0      0      0   8.0500     1  0  1  0  1

# %% [markdown]
# # Training and Testing Data

# %%
X=data.drop(['Survived'],axis=1)
Y=data['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,random_state=42,test_size=0.3) #70/30 ratio

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import classification_report
classification_report(y_test,prediction)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.78      0.88      0.83       122\n           1       0.81      0.67      0.73        92\n\n   micro avg       0.79      0.79      0.79       214\n   macro avg       0.79      0.78      0.78       214\nweighted avg       0.79      0.79      0.79       214\n'

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,prediction)
# Out:
# array([[107,  15],
#        [ 30,  62]], dtype=int64)

# %%
import matplotlib.pyplot as plt
import itertools
cm=confusion_matrix(y_test,prediction)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=45)
    plt.yticks(tick_marks,classes)
    # Only use the labels that appear in the data
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh=cm.max()/2
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,cm[i,j],horizontalalignment="center",color="white" if cm[i,j]>thresh else "black")
        
    plt.tight_layout()
    plt.xlabel('Predicted Label')
    plt.ylabel('True label')
cm_plot_labels=['0','1']
plot_confusion_matrix(cm,cm_plot_labels,title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[107  15]
#  [ 30  62]]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
#manually 107+62/(107+15+30+62)=78
# Out:
# 0.7897196261682243
